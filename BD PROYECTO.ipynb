-- %% [markdown]
-- # [db_Promaker]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [db_Promaker]    Script Date: 28/05/2024 11:49:00 ******/
CREATE DATABASE [db_Promaker]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'db_Promaker', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\db_Promaker.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'db_Promaker_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\db_Promaker_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [db_Promaker] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [db_Promaker].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [db_Promaker] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [db_Promaker] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [db_Promaker] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [db_Promaker] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [db_Promaker] SET ARITHABORT OFF 
GO
ALTER DATABASE [db_Promaker] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [db_Promaker] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [db_Promaker] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [db_Promaker] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [db_Promaker] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [db_Promaker] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [db_Promaker] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [db_Promaker] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [db_Promaker] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [db_Promaker] SET  DISABLE_BROKER 
GO
ALTER DATABASE [db_Promaker] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [db_Promaker] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [db_Promaker] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [db_Promaker] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [db_Promaker] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [db_Promaker] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [db_Promaker] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [db_Promaker] SET RECOVERY FULL 
GO
ALTER DATABASE [db_Promaker] SET  MULTI_USER 
GO
ALTER DATABASE [db_Promaker] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [db_Promaker] SET DB_CHAINING OFF 
GO
ALTER DATABASE [db_Promaker] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [db_Promaker] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [db_Promaker] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [db_Promaker] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'db_Promaker', N'ON'
GO
ALTER DATABASE [db_Promaker] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[ALMACEN]

-- %%
USE [db_Promaker]
GO

-- %%
/****** Object:  Table [dbo].[ALMACEN]    Script Date: 28/05/2024 11:49:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ALMACEN](
	[id_area] [int] NOT NULL,
	[nombre_area] [varchar](100) NULL,
	[num_estante] [int] NULL,
	[num_fila] [int] NULL,
	[num_columna] [int] NULL,
	[id] [int] NULL,
 CONSTRAINT [PK__ALMACEN__8A8C837B95346E7A] PRIMARY KEY CLUSTERED 
(
	[id_area] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ASIGNACION DE PROYECTO]

-- %%
/****** Object:  Table [dbo].[ASIGNACION DE PROYECTO]    Script Date: 28/05/2024 11:49:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ASIGNACION DE PROYECTO](
	[id_empleado] [int] IDENTITY(1,1) NOT NULL,
	[nombre_pyct] [varchar](100) NOT NULL,
	[fecha_proyect] [date] NULL,
 CONSTRAINT [PK_ASIGNACION DE PROYECTO] PRIMARY KEY CLUSTERED 
(
	[id_empleado] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CLIENTE]

-- %%
/****** Object:  Table [dbo].[CLIENTE]    Script Date: 28/05/2024 11:49:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CLIENTE](
	[nombre_cliente] [varchar](100) NOT NULL,
	[apellidos_cliente] [varchar](100) NULL,
	[num_cel] [varchar](12) NULL,
	[correo] [varchar](100) NULL,
	[tipo_cliente] [varchar](50) NULL,
	[direccion] [varchar](200) NULL,
	[dni] [varchar](20) NULL,
 CONSTRAINT [PK_CLIENTE] PRIMARY KEY CLUSTERED 
(
	[nombre_cliente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[COMPROBANTE DE PAGO]

-- %%
/****** Object:  Table [dbo].[COMPROBANTE DE PAGO]    Script Date: 28/05/2024 11:49:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[COMPROBANTE DE PAGO](
	[num_fac_blt] [varchar](50) NOT NULL,
	[fecha_emision] [date] NULL,
	[montoU_mtrl] [decimal](10, 2) NULL,
	[monto_total] [decimal](10, 2) NULL,
	[descripcion] [text] NULL,
 CONSTRAINT [PK_COMPROBANTE DE PAGO] PRIMARY KEY CLUSTERED 
(
	[num_fac_blt] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EMPLEADO]

-- %%
/****** Object:  Table [dbo].[EMPLEADO]    Script Date: 28/05/2024 11:49:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EMPLEADO](
	[id_empleado] [int] NOT NULL,
	[nombre_empleado] [varchar](100) NULL,
	[apellidos_empleado] [varchar](100) NULL,
	[permiso_area] [varchar](50) NULL,
	[correo] [varchar](100) NULL,
	[num_cel] [varchar](12) NULL,
	[direccion_empleado] [varchar](200) NULL,
	[tipo_empleado] [varchar](50) NULL,
 CONSTRAINT [PK__EMPLEADO__88B51394517125FD] PRIMARY KEY CLUSTERED 
(
	[id_empleado] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LOGIN]

-- %%
/****** Object:  Table [dbo].[LOGIN]    Script Date: 28/05/2024 11:49:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LOGIN](
	[id] [int] NOT NULL,
	[nombre] [varchar](50) NULL,
	[usuario_u] [varchar](50) NOT NULL,
	[contraseña_u] [varchar](50) NOT NULL,
	[tipo_usuario] [varchar](50) NULL,
 CONSTRAINT [PK__LOGIN__3213E83FE0A52D37] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MATERIALES]

-- %%
/****** Object:  Table [dbo].[MATERIALES]    Script Date: 28/05/2024 11:49:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MATERIALES](
	[codigo_mtrl] [int] NOT NULL,
	[nombre_mtrl] [varchar](100) NOT NULL,
	[precio_unitario] [decimal](10, 2) NOT NULL,
	[cantidad_mtrl] [int] NOT NULL,
	[unidad] [varchar](20) NOT NULL,
 CONSTRAINT [PK__MATERIAL__96B2ED4E31AA4309] PRIMARY KEY CLUSTERED 
(
	[codigo_mtrl] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[proveedor]

-- %%
/****** Object:  Table [dbo].[proveedor]    Script Date: 28/05/2024 11:49:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[proveedor](
	[num_ruc] [varchar](30) NOT NULL,
	[nombre_pvdr] [varchar](30) NULL,
	[cantidad] [varchar](50) NULL,
	[tipo_mtrl] [varchar](50) NULL,
	[unidad] [varchar](30) NULL,
PRIMARY KEY CLUSTERED 
(
	[num_ruc] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PROYECTO]

-- %%
/****** Object:  Table [dbo].[PROYECTO]    Script Date: 28/05/2024 11:49:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PROYECTO](
	[nombre_pyct] [varchar](100) NOT NULL,
	[estado] [varchar](50) NOT NULL,
	[fecha_inicio] [date] NULL,
	[fecha_final] [date] NULL,
 CONSTRAINT [PK_PROYECTO] PRIMARY KEY CLUSTERED 
(
	[nombre_pyct] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[suministrar]

-- %%
/****** Object:  Table [dbo].[suministrar]    Script Date: 28/05/2024 11:49:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[suministrar](
	[codigo_mtrl] [int] NOT NULL,
	[num_ruc] [varchar](30) NOT NULL,
	[id_materiales] [int] NULL,
 CONSTRAINT [pk_suministrar_materiales_proveedor] PRIMARY KEY CLUSTERED 
(
	[codigo_mtrl] ASC,
	[num_ruc] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CLIENTE]

-- %%
INSERT [dbo].[CLIENTE] ([nombre_cliente], [apellidos_cliente], [num_cel], [correo], [tipo_cliente], [direccion], [dni]) VALUES (N'cesar', N'andrey ', N'923616591', NULL, NULL, NULL, NULL)
INSERT [dbo].[CLIENTE] ([nombre_cliente], [apellidos_cliente], [num_cel], [correo], [tipo_cliente], [direccion], [dni]) VALUES (N'elizabet', NULL, NULL, NULL, NULL, NULL, NULL)
INSERT [dbo].[CLIENTE] ([nombre_cliente], [apellidos_cliente], [num_cel], [correo], [tipo_cliente], [direccion], [dni]) VALUES (N'maria', NULL, NULL, NULL, NULL, NULL, NULL)
GO

-- %% [markdown]
-- # [dbo].[LOGIN]

-- %%
INSERT [dbo].[LOGIN] ([id], [nombre], [usuario_u], [contraseña_u], [tipo_usuario]) VALUES (1, N'cesar chauca', N'cesar', N'admin', N'Admin')
INSERT [dbo].[LOGIN] ([id], [nombre], [usuario_u], [contraseña_u], [tipo_usuario]) VALUES (2, N'elizabeth', N'eli', N'usuario', N'Usuario')
GO

-- %% [markdown]
-- # [dbo].[MATERIALES]

-- %%
INSERT [dbo].[MATERIALES] ([codigo_mtrl], [nombre_mtrl], [precio_unitario], [cantidad_mtrl], [unidad]) VALUES (1, N'Taladros', CAST(10.00 AS Decimal(10, 2)), 1, N'1')
INSERT [dbo].[MATERIALES] ([codigo_mtrl], [nombre_mtrl], [precio_unitario], [cantidad_mtrl], [unidad]) VALUES (2, N'discos', CAST(5.00 AS Decimal(10, 2)), 1, N'1')
INSERT [dbo].[MATERIALES] ([codigo_mtrl], [nombre_mtrl], [precio_unitario], [cantidad_mtrl], [unidad]) VALUES (3, N'soldadura', CAST(6.00 AS Decimal(10, 2)), 1, N'1')
GO

-- %% [markdown]
-- # [FK_ALMACEN_EMPLEADO]

-- %%
ALTER TABLE [dbo].[ALMACEN]  WITH CHECK ADD  CONSTRAINT [FK_ALMACEN_EMPLEADO] FOREIGN KEY([id])
REFERENCES [dbo].[EMPLEADO] ([id_empleado])
GO
ALTER TABLE [dbo].[ALMACEN] CHECK CONSTRAINT [FK_ALMACEN_EMPLEADO]
GO

-- %% [markdown]
-- # [fk_almacen_login]

-- %%
ALTER TABLE [dbo].[ALMACEN]  WITH CHECK ADD  CONSTRAINT [fk_almacen_login] FOREIGN KEY([id])
REFERENCES [dbo].[LOGIN] ([id])
GO
ALTER TABLE [dbo].[ALMACEN] CHECK CONSTRAINT [fk_almacen_login]
GO

-- %% [markdown]
-- # [FK_ALMACEN_MATERIALES]

-- %%
ALTER TABLE [dbo].[ALMACEN]  WITH CHECK ADD  CONSTRAINT [FK_ALMACEN_MATERIALES] FOREIGN KEY([num_estante])
REFERENCES [dbo].[MATERIALES] ([codigo_mtrl])
GO
ALTER TABLE [dbo].[ALMACEN] CHECK CONSTRAINT [FK_ALMACEN_MATERIALES]
GO

-- %% [markdown]
-- # [FK_ASIGNACION DE PROYECTO_PROYECTO]

-- %%
ALTER TABLE [dbo].[ASIGNACION DE PROYECTO]  WITH CHECK ADD  CONSTRAINT [FK_ASIGNACION DE PROYECTO_PROYECTO] FOREIGN KEY([nombre_pyct])
REFERENCES [dbo].[PROYECTO] ([nombre_pyct])
GO
ALTER TABLE [dbo].[ASIGNACION DE PROYECTO] CHECK CONSTRAINT [FK_ASIGNACION DE PROYECTO_PROYECTO]
GO

-- %% [markdown]
-- # [FK_EMPLEADO_ASIGNACION DE PROYECTO]

-- %%
ALTER TABLE [dbo].[EMPLEADO]  WITH CHECK ADD  CONSTRAINT [FK_EMPLEADO_ASIGNACION DE PROYECTO] FOREIGN KEY([id_empleado])
REFERENCES [dbo].[ASIGNACION DE PROYECTO] ([id_empleado])
GO
ALTER TABLE [dbo].[EMPLEADO] CHECK CONSTRAINT [FK_EMPLEADO_ASIGNACION DE PROYECTO]
GO

-- %% [markdown]
-- # [FK_PROYECTO_COMPROBANTE DE PAGO]

-- %%
ALTER TABLE [dbo].[PROYECTO]  WITH CHECK ADD  CONSTRAINT [FK_PROYECTO_COMPROBANTE DE PAGO] FOREIGN KEY([estado])
REFERENCES [dbo].[COMPROBANTE DE PAGO] ([num_fac_blt])
GO
ALTER TABLE [dbo].[PROYECTO] CHECK CONSTRAINT [FK_PROYECTO_COMPROBANTE DE PAGO]
GO

-- %% [markdown]
-- # [FK_suministrar_MATERIALES]

-- %%
ALTER TABLE [dbo].[suministrar]  WITH CHECK ADD  CONSTRAINT [FK_suministrar_MATERIALES] FOREIGN KEY([codigo_mtrl])
REFERENCES [dbo].[MATERIALES] ([codigo_mtrl])
GO
ALTER TABLE [dbo].[suministrar] CHECK CONSTRAINT [FK_suministrar_MATERIALES]
GO

-- %% [markdown]
-- # [FK_suministrar_proveedor]

-- %%
ALTER TABLE [dbo].[suministrar]  WITH CHECK ADD  CONSTRAINT [FK_suministrar_proveedor] FOREIGN KEY([num_ruc])
REFERENCES [dbo].[proveedor] ([num_ruc])
GO
ALTER TABLE [dbo].[suministrar] CHECK CONSTRAINT [FK_suministrar_proveedor]
GO

-- %% [markdown]
-- # [db_Promaker]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [db_Promaker] SET  READ_WRITE 
GO
